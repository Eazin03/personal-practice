# %%
import pandas as pd

# 创建DataFrame
df1 = pd.DataFrame([
    {'姓名':'张三','语文':85,'数学': 92,'英语': 78},
    {'姓名':'李四','语文':78,'数学':88,'英语':95},
    {'姓名':'王五','语文':92,'数学':96,'英语': 89}
])

df2 = pd.DataFrame({
    '姓名':['张三','李四','王五'],
    '语文':[85,78,92],
    '数学':[92,88,96],
    '英语':[78,95,89]
})

df3 = pd.DataFrame([
    ('张三',85,92,78),
    ('李四',78,88,95),
    ('王五',92,96,89)
],columns=['姓名','语文','数学','英语'])

df4 = pd.DataFrame([
    ['张三',85,92,78],
    ['李四',78,88,95],
    ['王五', 92, 96, 89]
],columns=['姓名','语文','数学','英语'],index=['a', 'b', 'c'])

# DateFrame 常见属性 - index , columns , values , dtypes ,  shape
# df4.index# index: 表示行索引
# df4.index.tolist()# 转换为列表
# df4.columns.tolist()# columns: 表示列名
# df4.values# values: 获取DataFrame中的数据
# df4.dtypes# dtypes: 获取DataFrame中列的数据类型
# df4.shape# shape: 获取DataFrame的行数和列数
# Out:
# 姓名    object
# 语文     int64
# 数学     int64
# 英语     int64
# dtype: object

# %%
# 创建Series
s1 = pd.Series([1,2,3,4,5])
s2 = pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
s3 = pd.Series({'a':1,'b':2,'c':3,'d':4,'e':5})

s4 = df4['语文']

# Series 常见属性 - index , values , dtype , size , shape
# s4.index.tolist()# index: 获取Series的索引
s4.values.tolist()# values: 获取Series中的数据
# s4.dtype# dtype: 获取Series的数据类型
# s4.size# size: 获取Series的长度
# s4.shape# shape: 获取Series的行数
# Out:
# [85, 78, 92]
